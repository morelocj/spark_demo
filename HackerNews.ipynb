# %% [markdown]
# HackerNews: https://github.com/HackerNews/API
#
# Take time to read and understand the Documentation.
# Items
# All types of posts stories, comments, jobs, asks, polls are ALL considered items
# REQUIRED properties are in bold, not all properties will be included for every item
# There is a “by” property which is the username of the item’s author. If we go down to the user properties you will see that there is not a username property. There is an “id” which is defined in the documentation as the username. We have been traditionally working with “id” as a numeric value. This is not the case here.
# Users
# Each User has a “submitted” property that is a list of all of their posted items
# As mentioned above the “id” property is the username
# MAX ID endpoint. We don’t have a max number of pages, etc. But we do have a way to request the max item id, which gives us an idea of the scale of data we are working with
#
#
# Problem prompts
# 1. Create a list that stores a certain number of items to work off of. We have the range of item ids from the MAX ID endpoint. I suggest that you start small and expand the dataset
# 2. Write a function to display all the items written by a certain user
# 3. Write a function to display the average score of all items
# 4. Write a function to display the average score of the items by a certain user
# 5. Write a function to display all of the comments of an item(this is a more challenging task)
# 6. Write a function to display all of the items created in a certain year. You can expand on this to add additional parameters: Month, Day, etc. Any combo you choose or any single value
# 7. Write a function to display the total number of deleted items.
# 8. Write a function to display the total number of live items.
# 9. Write a function to display the total number of deleted items without any comments
# 10. Write a function to find which item has the most total comments
# 11. Write a function to find which user made the most comments.
# 12. Write a function to see which hour of the day is the most common for a user to post an item

# %% [markdown]
# 1. Create a list that stores a certain number of items to work off of. We have the range of item ids from the MAX ID endpoint. I suggest that you start small and expand the dataset

# %%
import requests
import json
from pprint import pp

# %%
baseurl = 'https://hacker-news.firebaseio.com/v0/item/'
item = 34342638

data = []
for _ in range(500):
    sitem = str(item)+'.json'
    response = requests.get(baseurl+sitem)
    new_response = response.json()
    data.append(new_response)
    item -= 1

pp(data)
# Out:
# [{'by': 'rntn',
#   'descendants': 0,
#   'id': 34342638,
#   'score': 1,
#   'time': 1673462791,
#   'title': 'Global Risks Report 2023',
#   'type': 'story',
#   'url': 'https://www.weforum.org/reports/global-risks-report-2023/'},
#  {'by': 'shadowgovt',
#   'id': 34342637,
#   'kids': [34343131],
#   'parent': 34342167,
#   'text': '&gt; Actually, this is a perfect example of something that '
#           'isn&#x27;t going to get the company into legal trouble<p>Rizzo v. '
#           'Yovino, 9th Circuit ruling, indicates that basing present pay on '
#           'past pay may violate the Equal Pay Act of 1963 (<a '
#           'href="https:&#x2F;&#x2F;www.forbes.com&#x2F;sites&#x2F;ericbachman&#x2F;2020&#x2F;03&#x2F;13&#x2F;past-salary-cannot-excuse-gender-pay-discrimination-court-rules&#x2F;?sh=5f416d2364d5" '
#           'rel="nofollow">https:&#x2F;&#x2F;www.forbes.com&#x2F;sites&#x2F;ericbachman&#x2F;2020&#x2F;03&#x2F;13&#x2F;past-sal...</a>).<p>... '
#           'but more importantly, this case has entangled the Fresno County '
#           'public school system for over a decade. That&#x27;s expensive '
#           'relative to the alternative of... Not doing that.',
#   'time': 1673462790,
#   'type': 'comment'},
#  {'by': 'tosh',
#   'descendants': 0,
#   'id': 34342636,
#   'score': 2,
#   'time': 1673462786,
#   'title': 'iOS 16.3, macOS Ventura 13.2 Betas: Physical Apple ID Security '
#            'Keys',
#   'type': 'story',
#   'url': 'https://www.macrumors.com/2022/12/14/ios-16-3-beta-security-keys/'},
#  {'by': 'Tomte',
#   'descendants': 0,
#   'id': 34342635,
#   'score': 1,
#   'time': 1673462781,
#   'title': 'Rainbow Color Map Still Considered Harmful (2007) [pdf]',
#   'type': 'story',
#   'url': 'https://raw.githubusercontent.com/djoshea/matlab-utils/master/libs/perceptuallyImprovedColormaps/Rainbow%20Color%20Map%20-Still-%20Considered%20Harmful.pdf'},
#  {'by': 'bonestamp2',
#   'id': 34342634,
#   'parent': 34330644,
#   'text': 'I wish the NOAA API was reliable. I&#x27;d pay for it if they could '
#           'make it reliable (and they could probably make it reliable if they '
#           'charged for it).',
#   'time': 1673462775,
#   'type': 'comment'},
#  {'by': 'Tomte',
#   'descendants': 0,
#   'id': 34342633,
#   'score': 1,
#   'time': 1673462773,
#   'title': 'Why Specs Matter (2004)',
#   'type': 'story',
#   'url': 'https://web.archive.org/web/20051016203842/http://diveintomark.org/archives/2004/08/16/specs'},
#  {'by': 'arrowsmith',
#   'id': 34342632,
#   'parent': 34342218,
#   'text': 'The course does cover LiveView - see e.g. lessons 38, 45, 49.<p>I '
#           'just realised that the sales page says the course '
#           '<i>doesn&#x27;t</i> cover LiveView, whoops, that&#x27;s out of '
#           'date. Needs fixing.',
#   'time': 1673462768,
#   'type': 'comment'},
#  {'by': 'ghaff',
#   'id': 34342631,
#   'parent': 34341724,
#   'text': 'I didn&#x27;t and don&#x27;t do a lot of software development. I '
#           'was a product manager for a long time and then an IT industry '
#           'analysts. As a product manager, to pick on one particular point, we '
#           'had very cursory competitive information. We had some expensive '
#           'subscriptions to analysts who essentially acted as a clearinghouse '
#           'for data sheets that companies couldn&#x27;t get from each other '
#           'directly. But it tended to be very shallow and '
#           'out-of-date.<p>Certainly not everything is on the web with or '
#           'without paywalls. And, as when I was doing software development at '
#           'night pre-web, I could just have a library of books. But for a lot '
#           'of things, you made do with taking longer, being more shallow, and '
#           'making more mistakes.',
#   'time': 1673462762,
#   'type': 'comment'},
#  {'by': 'pier25',
#   'id': 34342630,
#   'parent': 34340057,
#   'text': 'If you can solve a problem without a microservice then probably '
#           'it&#x27;s not the right tool for the job.',
#   'time': 1673462756,
#   'type': 'comment'},
#  {'by': 'adam_arthur',
#   'id': 34342629,
#   'parent': 34342365,
#   'text': 'Home prices are in decline, and new home construction (SFH + MFH) '
#           'is at an all time high (though dipped a bit recently). Rents are '
#           'actually in deflation mode the past few months. If rates stay high, '
#           'home prices will fall, absolutely. Unemployment will rise '
#           'too.<p>Agreed that congress can do more to help though. Incentives '
#           'are poorly structured to promote housing affordability.',
#   'time': 1673462754,
#   'type': 'comment'},
#  {'by': 'BWStearns',
#   'id': 34342628,
#   'parent': 34336759,
#   'text': 'Foreflight is the best app-for-purpose I&#x27;ve ever used. The '
#           'smart ruler function is amazing on so many levels and I hate '
#           '[Google|Apple] Maps every time I use them and want the smart ruler.',
#   'time': 1673462749,
#   'type': 'comment'},
#  {'by': 'g42gregory',
#   'descendants': 0,
#   'id': 34342627,
#   'score': 1,
#   'time': 1673462749,
#   'title': 'Intel Unveils 4th Gen Xeon Scalable Sapphire Rapids Processor '
#            'Line-Up Full Specs',
#   'type': 'story',
#   'url': 'https://hothardware.com/news/intel-unveils-4th-gen-xeon-scalable-cpus'},
#  {'by': 'jimmydddd',
#   'id': 34342626,
#   'parent': 34339116,
#   'text': 'I wish I had these resources when I was in school. I was studying '
#           'EE back in the late &#x27;80s.  I had a textbook with maybe two '
#           'worked out examples for each concept.  The answers to the '
#           'odd-numbered homework problems were in the back, but just as a '
#           'number.  So if I worked out a long problem and got, say, 5 as an '
#           'answer, and the answer in the back was, say, -5, I had no real way '
#           'of knowing if I made a mistake somewhere, or if the answer in the '
#           'back of the book was incorrect. Working in groups was discouraged '
#           'as a kind of cheating because you were supposed to do your own '
#           'work.  The professors weren&#x27;t that interested in teaching '
#           'because they felt they were there more to rank us.  And the '
#           'teaching assistants were mostly foreign-born with limited spoken '
#           'English skills.',
#   'time': 1673462747,
#   'type': 'comment'},
#  {'by': 'klysm',
#   'id': 34342625,
#   'kids': [34343910, 34342878],
#   'parent': 34330198,
#   'text': 'Make becomes a pretty terrible tool at a fairly low level of '
#           'complexity. I would never choose it voluntarily to build things.',
#   'time': 1673462736,
#   'type': 'comment'},
#  {'by': 'amalgamated_inc',
#   'id': 34342624,
#   'kids': [34344820, 34342732],
#   'parent': 34338629,
#   'text': 'Wow, looks awesome! I love these indie sidescrollers.<p>Will it be '
#           'available for Linux, maybe on GOG?',
#   'time': 1673462735,
#   'type': 'comment'},
#  {'by': 'freedom2099',
#   'id': 34342623,
#   'parent': 34340528,
#   'text': 'Or live in a country that by law paid leave for sickness (yours or '
#           'your kids) and vacations (I have 35 days off a year… and I am '
#           'obliged to take them all)!',
#   'time': 1673462734,
#   'type': 'comment'},
#  {'by': 'paulpauper',
#   'descendants': 0,
#   'id': 34342622,
#   'score': 1,
#   'time': 1673462729,
#   'title': 'The Poland/Malaysia Model',
#   'type': 'story',
#   'url': 'https://noahpinion.substack.com/p/the-polandmalaysia-model'},
#  {'by': 'progbits',
#   'id': 34342621,
#   'parent': 34342344,
#   'text': 'Agreed. But I feel like that is still a step ahead of RPi where you '
#           'get random firmware blobs for the GPU without which it won&#x27;t '
#           'even boot.',
#   'time': 1673462721,
#   'type': 'comment'},
#  {'by': 'headalgorithm',
#   'descendants': 0,
#   'id': 34342620,
#   'score': 1,
#   'time': 1673462719,
#   'title': 'How I run a company with ADHD (2019)',
#   'type': 'story',
#   'url': 'https://www.andrewaskins.com/how-i-run-a-company-with-adhd/'},
#  {'by': 'BrookfieldBrief',
#   'dead': True,
#   'id': 34342619,
#   'score': 1,
#   'time': 1673462719,
#   'type': 'story'},
#  {'by': 'winternett',
#   'id': 34342618,
#   'parent': 34342091,
#   'text': 'Progress has been underwhelming because the innovations are not '
#           'stunning to consumers when pricing goes up every year while '
#           'connectivity is becoming more and more of a metered '
#           'utility.<p>Technological progress too often is based upon what will '
#           'increase profit for shareholder driven companies, rather than for '
#           'adding real value and simplifying lives of the consumers it was '
#           'meant to serve.<p>There is a plateau for how much shareholder '
#           'driven technology can sustain itself, and that ends exactly where '
#           'consumers are no longer eagerly driven to buy new consumer products '
#           'and services. It is being demonstrated a lot lately as despite many '
#           'sites having an astronomical number of users, many of them rarely '
#           'log in. It&#x27;s time for companies to start paying attention to '
#           'alternate metrics to drive their business models than just '
#           'subscriptions, market investment, and net profit. Pricing and '
#           'reliability will likely be the most competitive points in economies '
#           'like this.',
#   'time': 1673462719,
#   'type': 'comment'},
#  {'by': 'red-iron-pine',
#   'id': 34342617,
#   'parent': 34341096,
#   'text': 'Pay ain&#x27;t bad either.  Not SWE III at a FAANG level but '
#           'certainly not bad',
#   'time': 1673462715,
#   'type': 'comment'},
#  {'by': 'p_l',
#   'id': 34342616,
#   'parent': 34342334,
#   'text': 'The reality is that the higher capacity goes not towards giving you '
#           'more speed, but towards supporting more users per cell.',
#   'time': 1673462713,
#   'type': 'comment'},
#  {'by': 'screwturner68',
#   'id': 34342615,
#   'parent': 34333951,
#   'text': 'Interesting.  My first visit could best be described as invasive, '
#           'the doc checked every part of my body including places that have '
#           'never seen sunlight.  I was a bit surprised where they checked but '
#           'it&#x27;s just the job. I looked into digital imaging, they are '
#           'even working on AI to identify changes but from what I read, at '
#           'this time the best method is the old fashion look and see.',
#   'time': 1673462711,
#   'type': 'comment'},
#  {'deleted': True,
#   'id': 34342614,
#   'parent': 34342310,
#   'time': 1673462711,
#   'type': 'comment'},
#  {'by': 'charcircuit',
#   'id': 34342613,
#   'kids': [34344794, 34343536],
#   'parent': 34330198,
#   'text': '&gt;People routinely point out that npm&#x2F;yarn scripts are '
#           'shockingly slow to start<p>The claim that 157 ms and 126 ms is '
#           '&quot;shockingly slow&quot; is quite an exaggeration.',
#   'time': 1673462710,
#   'type': 'comment'},
#  {'by': 'xxpor',
#   'id': 34342612,
#   'parent': 34342430,
#   'text': 'Looks like you&#x27;re not wrong: <a '
#           'href="https:&#x2F;&#x2F;patents.google.com&#x2F;patent&#x2F;US9577420B2&#x2F;en" '
#           'rel="nofollow">https:&#x2F;&#x2F;patents.google.com&#x2F;patent&#x2F;US9577420B2&#x2F;en</a>',
#   'time': 1673462710,
#   'type': 'comment'},
#  {'by': 'efunction',
#   'dead': True,
#   'id': 34342611,
#   'score': 1,
#   'time': 1673462710,
#   'type': 'story'},
#  {'by': 'paulpauper',
#   'descendants': 0,
#   'id': 34342610,
#   'score': 1,
#   'time': 1673462703,
#   'title': 'The Shocking Truth about Cheating in College',
#   'type': 'story',
#   'url': 'https://www.youtube.com/watch?v=VpIvpGfnCe0'},
#  {'by': 'flavius29663',
#   'id': 34342609,
#   'kids': [34344907],
#   'parent': 34342269,
#   'text': '&quot;rolling blackout&quot; is a very specific term used when '
#           'grids are overloaded (usually when not enough generation is '
#           'happening), which means that the operator is intentionally cutting '
#           'power to some areas to save on energy. The areas keep changing '
#           '(such that each area is out of power for just a few hours at a '
#           'time), hence the name &quot;rolling&quot;.<p>The OP said that the '
#           'eastern storm is proof the grid is not resilient enough because of '
#           'rolling blackouts, which I find hard to believe without some more '
#           'sources&#x2F;reasoning.',
#   'time': 1673462702,
#   'type': 'comment'},
#  {'by': 'jeremy_wiebe',
#   'id': 34342608,
#   'parent': 34342485,
#   'text': 'This post is referring to NSCalendar and Swift&#x27;s Calendar '
#           'class.<p>&gt; NSCalendar objects encapsulate information about '
#           'systems of reckoning time in which the beginning, length, and '
#           'divisions of a year are defined.<p>&gt; The Swift overlay to the '
#           'Foundation framework provides the Calendar structure, which bridges '
#           'to the NSCalendar class.<p><a '
#           'href="https:&#x2F;&#x2F;developer.apple.com&#x2F;documentation&#x2F;foundation&#x2F;nscalendar" '
#           'rel="nofollow">https:&#x2F;&#x2F;developer.apple.com&#x2F;documentation&#x2F;foundation&#x2F;nscalen...</a>',
#   'time': 1673462695,
#   'type': 'comment'},
#  {'by': 'erehweb',
#   'id': 34342607,
#   'parent': 34342412,
#   'text': 'Paying out carried over leave is likely a legal requirement or '
#           'close to one.',
#   'time': 1673462693,
#   'type': 'comment'},
#  {'by': 'enragedcacti',
#   'id': 34342606,
#   'parent': 34342532,
#   'text': '&gt; but the underlying concept is incoherent<p>what specifically '
#           'is incoherent about it? I attempted to address that by noting that '
#           'active areas of research will always have mutually incompatible '
#           'theories that are incoherent when taken together, but perhaps I '
#           'misunderstood what you meant.',
#   'time': 1673462677,
#   'type': 'comment'},
#  {'deleted': True,
#   'id': 34342605,
#   'parent': 34336282,
#   'time': 1673462677,
#   'type': 'comment'},
#  {'by': 'kube-system',
#   'id': 34342604,
#   'parent': 34342544,
#   'text': 'It&#x27;s less about the format being portable, and more that the '
#           'software is portable along with the files.  You need both to be '
#           'able to work with them.',
#   'time': 1673462676,
#   'type': 'comment'},
#  {'by': 'kaycebasques',
#   'descendants': 0,
#   'id': 34342603,
#   'score': 2,
#   'time': 1673462674,
#   'title': 'English Letter Frequency',
#   'type': 'story',
#   'url': 'https://pi.math.cornell.edu/~mec/2003-2004/cryptography/subs/frequencies.html'},
#  {'by': 'jjeaff',
#   'id': 34342602,
#   'kids': [34344558, 34344347],
#   'parent': 34341942,
#   'text': 'I would think more people on HN would understand the importance of '
#           'data. Its pretty hard to change something that you aren&#x27;t '
#           'tracking.<p>Perhaps Europe would benefit from more data in this '
#           'regard?',
#   'time': 1673462674,
#   'type': 'comment'},
#  {'by': 'dfps',
#   'descendants': 8,
#   'id': 34342601,
#   'kids': [34343292,
#            34343758,
#            34344379,
#            34343182,
#            34344252,
#            34343275,
#            34344644,
#            34344589],
#   'score': 15,
#   'text': 'Do those two things balance out? (Some estimates put the stock '
#           'market loss at around $7t or $9t, additionally).',
#   'time': 1673462670,
#   'title': 'Does the $2T crypto loss balance out the $2T money supply '
#            'expansion?',
#   'type': 'story'},
#  {'by': 'tobr',
#   'id': 34342600,
#   'kids': [34342940, 34343057],
#   'parent': 34342309,
#   'text': '&gt; Is there a use case to use this on a phone?<p>You should '
#           'probably be thinking of it the opposite way, is there a reason '
#           'people wouldn’t use it on their phones? It’s on the web, the web is '
#           'on your phone! People use their phones all the time for '
#           'work-related things so they are going to expect this to be '
#           'available there, too.',
#   'time': 1673462668,
#   'type': 'comment'},
#  {'by': 'LinuxBender',
#   'id': 34342599,
#   'kids': [34344071, 34342738],
#   'parent': 34342256,
#   'text': 'For what it&#x27;s worth that domain in your repo is also listed in '
#           'the 1Hosts block-list [1] but only in the Xtra category, not sure '
#           'why.  It seems that is a known malware site.  Oddly enough it is '
#           'not listed in the PiHoleBlocklist [2]<p>[1] - <a '
#           'href="https:&#x2F;&#x2F;github.com&#x2F;badmojr&#x2F;1Hosts">https:&#x2F;&#x2F;github.com&#x2F;badmojr&#x2F;1Hosts</a> '
#           '[listed but only in Xtra]<p>[2] - <a '
#           'href="https:&#x2F;&#x2F;github.com&#x2F;Perflyst&#x2F;PiHoleBlocklist.git">https:&#x2F;&#x2F;github.com&#x2F;Perflyst&#x2F;PiHoleBlocklist.git</a>  '
#           '[not listed]',
#   'time': 1673462668,
#   'type': 'comment'},
#  {'by': 'hkmaxpro',
#   'descendants': 0,
#   'id': 34342598,
#   'score': 3,
#   'time': 1673462665,
#   'title': 'Microsoft employees are getting unlimited time off',
#   'type': 'story',
#   'url': 'https://www.theverge.com/2023/1/11/23550470/microsoft-employees-unlimited-time-off-2023'},
#  {'by': 'taylodl',
#   'id': 34342597,
#   'parent': 34339698,
#   'text': 'Layoffs have <i>always</i> been a part of tech. I&#x27;ve been '
#           'laid-off three times during my nearly 40 year career: in 2 '
#           'instances the company folded and in the other the project was '
#           'cancelled and everybody working on it was let go.<p>That&#x27;s the '
#           'nature of this beast. Companies get bullish on the future and over '
#           'hire, then they have to layoff. Completely new bet-the-company '
#           'projects get launched and then turns out to be a bigger bite than '
#           'the company could chew. It happens.<p>The rule-of-thumb I was '
#           'always taught growing up in tech (and I started in the '
#           'mid&#x27;80&#x27;s) was expect to be laid-off at some point in your '
#           'career and always make sure you have six months of expenses on hand '
#           'to weather a layoff. It was good advice then, and it&#x27;s good '
#           'advice now.',
#   'time': 1673462661,
#   'type': 'comment'},
#  {'by': 'MrOwnPut',
#   'id': 34342596,
#   'kids': [34343672],
#   'parent': 34342341,
#   'text': 'The American colonies supplied the Brits with cotton. The system '
#           'was setup to do so by UK. UK was buying the slave picked cotton '
#           'well after they abolished&#x2F;outsourced slavery.<p>The UK even '
#           'continued slavery in Indian colonies until 1843. They only '
#           'abolished sugar plantations because it was not profitable '
#           'anymore.<p>If the American colonies didn&#x27;t rebel from the UK, '
#           'they may have not abolished the cotton plantations themselves '
#           'because they highly depended on it.',
#   'time': 1673462659,
#   'type': 'comment'},
#  {'by': 'FearNotDaniel',
#   'id': 34342595,
#   'kids': [34343713],
#   'parent': 34336676,
#   'text': 'I remember that feeling, watching John Hughes films as a teenager '
#           'in northern England. Though sometimes part of his gift was that the '
#           'sense of adolescent angst was so universal, I could identify with '
#           'some of the characters despite the exotic setting. And in some '
#           'cases (e.g. Pretty in Pink) Hughes managed to show us this world of '
#           'spoilt rich kids through the eyes of someone less '
#           'privileged.<p>Tangential, but I think part of the genius of the '
#           'more recent Sex Education (Netflix) is that the setting is '
#           'definitely British (accents, landscape) and contemporary '
#           '(smartphones, fashions) and yet brilliantly evokes a British '
#           'kid&#x27;s fantasies of what a High School <i>should</i> be like '
#           'after watching too many 80s American movies.',
#   'time': 1673462658,
#   'type': 'comment'},
#  {'by': 'tomohawk',
#   'descendants': 0,
#   'id': 34342594,
#   'score': 3,
#   'time': 1673462643,
#   'title': 'Attorney General Expands Civil Rights Investigation to Fairfax '
#            'County Schools',
#   'type': 'story',
#   'url': 'https://www.oag.state.va.us/media-center/news-releases/2521-january-09-2023-attorney-general-miyares-expands-civil-rights-investigation-to-fairfax-county-public-schools-system'},
#  {'by': 'spoiler',
#   'id': 34342593,
#   'kids': [34344015],
#   'parent': 34342133,
#   'text': 'Didn&#x27;t recent research show that&#x27;s it&#x27;s usually not '
#           'a simple case of &quot;chemical imbalance&quot;. So, '
#           'antidepressants on their own won&#x27;t do much. Maybe getting '
#           'kicked out of this &quot;unhealthy homeostasis&quot; by medications '
#           'helps some people find new ways of coping&#x2F;perceiving their '
#           'life, but AFAIK that&#x27;s not the default case. So, they should '
#           'be administered with therapy (and no, I don&#x27;t consider therapy '
#           'seeing them once every two months to renew your subscription lol)',
#   'time': 1673462641,
#   'type': 'comment'},
#  {'by': 'welshwelsh',
#   'id': 34342592,
#   'kids': [34343152],
#   'parent': 34340202,
#   'text': 'Making employees manually fetch products is not a solution.  '
#           'That&#x27;s way too labor intensive, and there&#x27;s no excuse to '
#           'make people waste their time doing menial labor like that in '
#           'today&#x27;s world.<p>I like what Amazon has in their Fresh stores, '
#           'where you use a credit card to enter and an automated system tracks '
#           'what you take and sends you the bill.',
#   'time': 1673462641,
#   'type': 'comment'},
#  {'by': 'linsomniac',
#   'id': 34342591,
#   'kids': [34342742],
#   'parent': 34342166,
#   'text': 'Where does RCS fit into this?',
#   'time': 1673462639,
#   'type': 'comment'},
#  {'by': 'joshma',
#   'descendants': 0,
#   'id': 34342590,
#   'score': 3,
#   'time': 1673462636,
#   'title': 'Multi-Step Workflows in Airplane',
#   'type': 'story',
#   'url': 'https://www.airplane.dev/blog/introducing-powerful-multi-step-workflows-in-airplane'},
#  {'by': 'michael1999',
#   'id': 34342589,
#   'kids': [34344504],
#   'parent': 34340012,
#   'text': 'Anyone know how verification works?',
#   'time': 1673462628,
#   'type': 'comment'},
#  {'by': 'marsupialtail_2',
#   'id': 34342588,
#   'kids': [34344264, 34344337],
#   'parent': 34342190,
#   'text': 'I think the blog post should point out very early that Onehouse is '
#           'a Hudi company. There are some other recent benchmarks published in '
#           'CIDR by Databricks that might paint a different picture: <a '
#           'href="https:&#x2F;&#x2F;petereliaskraft.net&#x2F;res&#x2F;cidr_lakehouse.pdf" '
#           'rel="nofollow">https:&#x2F;&#x2F;petereliaskraft.net&#x2F;res&#x2F;cidr_lakehouse.pdf</a>',
#   'time': 1673462628,
#   'type': 'comment'},
#  {'by': 'counttheforks',
#   'id': 34342587,
#   'parent': 34342361,
#   'text': 'I haven&#x27;t asked once yet. Consider this the first and only '
#           'time.',
#   'time': 1673462617,
#   'type': 'comment'},
#  {'by': 'techie128',
#   'id': 34342586,
#   'kids': [34342811, 34344685],
#   'parent': 34342180,
#   'text': '&gt; The annoying part is when I plug in some faulty device that is '
#           'not immediately dangerous<p>Do you mind, re-reading that statement? '
#           'I don&#x27;t even understand that argument. You should not be '
#           'plugging in <i>faulty</i> devices in the first place...',
#   'time': 1673462612,
#   'type': 'comment'},
#  {'by': 'yters',
#   'dead': True,
#   'id': 34342585,
#   'score': 1,
#   'time': 1673462610,
#   'type': 'story'},
#  {'by': 'nindalf',
#   'id': 34342584,
#   'parent': 34342475,
#   'text': '<a href="https:&#x2F;&#x2F;archive.is&#x2F;474mc" '
#           'rel="nofollow">https:&#x2F;&#x2F;archive.is&#x2F;474mc</a>',
#   'time': 1673462607,
#   'type': 'comment'},
#  {'by': 'alephnerd',
#   'id': 34342583,
#   'parent': 34341824,
#   'text': 'Amen to that!<p>At least talking to people who went through 2001 '
#           'and 2008, it looks like there are more opportunities across the '
#           'board now. If you got laid off from $randomYCStartup as a SWE or '
#           'SRE, you can still land a decent paying IC role at one of the 100s '
#           'of upper market companies that exist. BoA, Honeywell, Target, etc '
#           'are still hiring SWEs and paying decent salaries, as are the '
#           'hundreds of upper market B2B tech companies (eg. Okta, Meraki, '
#           'Oracle, etc). It may not seem sexy like working at Google or Meta, '
#           'but it ain&#x27;t a bad living either. Sadly, a lot of my peers '
#           'have this sense of hubris that anything less than FAANG or a late '
#           'stage startup spending tens of millions of dollars in PR is career '
#           'suicide, which is honestly stupid in an industry as skill oriented '
#           'as ours',
#   'time': 1673462598,
#   'type': 'comment'},
#  {'by': 'johnohara',
#   'id': 34342582,
#   'parent': 34340502,
#   'text': 'The Artist: Richard Ankrom  <a '
#           'href="https:&#x2F;&#x2F;ankrom.org&#x2F;" '
#           'rel="nofollow">https:&#x2F;&#x2F;ankrom.org&#x2F;</a><p>The Public '
#           'Service: Guerrilla Public Service 2011  <a '
#           'href="https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=Clgl63CWOkM">https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=Clgl63CWOkM</a>',
#   'time': 1673462593,
#   'type': 'comment'},
#  {'by': 'mpweiher',
#   'id': 34342581,
#   'kids': [34342782, 34343123, 34342775, 34342810, 34343147],
#   'parent': 34342476,
#   'text': 'Things will get even slower.',
#   'time': 1673462589,
#   'type': 'comment'},
#  {'by': 'shagie',
#   'id': 34342580,
#   'parent': 34336985,
#   'text': 'Having just downloaded and poked at it, it looks very nice and '
#           'familiar for those who want a Dark Sky type interface.  The '
#           '&quot;oh, that&#x27;s a feature I&#x27;d like&quot; comes at a bit '
#           'of &quot;that&#x27;s behind an IAP&quot;, but I suspect I&#x27;ll '
#           'be adding it to my weather section.<p>Thank you for introducing me '
#           'to it.',
#   'time': 1673462582,
#   'type': 'comment'},
#  {'by': 'bullen',
#   'id': 34342579,
#   'kids': [34342678],
#   'parent': 34342514,
#   'text': 'We&#x27;ll see, if you need a heatsink for this here is one I '
#           'bought which should fit: <a '
#           'href="http:&#x2F;&#x2F;www.enzotech.com&#x2F;cnb_s1l.htm" '
#           'rel="nofollow">http:&#x2F;&#x2F;www.enzotech.com&#x2F;cnb_s1l.htm</a><p>Not '
#           'going to debate the gflops&#x2F;w yet, but Raspberry 4 cores are '
#           'also around 1W each and they kick ass compared to even M1 (much '
#           'worse OFC, but per $&#x2F;openess they still win imo)',
#   'time': 1673462577,
#   'type': 'comment'},
#  {'by': 'giaour',
#   'id': 34342578,
#   'parent': 34342330,
#   'text': 'If I wanted to set up a botnet, bundling malware in a dumb game and '
#           'then putting the exe on the internet for free seems like a decent '
#           'start',
#   'time': 1673462574,
#   'type': 'comment'},
#  {'by': 'amalgamated_inc',
#   'id': 34342577,
#   'parent': 34334051,
#   'text': 'Everything I like is a human right',
#   'time': 1673462558,
#   'type': 'comment'},
#  {'by': 'ConceitedCode',
#   'id': 34342576,
#   'parent': 34341968,
#   'text': 'Wikipedia page for the incident - <a '
#           'href="https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Aurora,_Texas,_UFO_incident" '
#           'rel="nofollow">https:&#x2F;&#x2F;en.wikipedia.org&#x2F;wiki&#x2F;Aurora,_Texas,_UFO_incident</a>',
#   'time': 1673462554,
#   'type': 'comment'},
#  {'by': 'andrewfromx',
#   'id': 34342575,
#   'kids': [34342855],
#   'parent': 34342166,
#   'text': 'I still remember the day when it dawned on me that everyone, like '
#           'even cool people, could get SMS messages. It was that tipping point '
#           'when enough people had phones 24&#x2F;7 and suddenly it wasn&#x27;t '
#           'a very nerdy thing to do. Pre this time, the idea of sending an '
#           'email to ask someone out for a date for example was just laughable. '
#           'But a txt? It was very different. Still to this day if you meet '
#           'someone new and get &quot;their number&quot; it&#x27;s the way.',
#   'time': 1673462553,
#   'type': 'comment'},
#  {'by': 'baptiste313',
#   'descendants': 1,
#   'id': 34342574,
#   'kids': [34342802],
#   'score': 3,
#   'time': 1673462551,
#   'title': 'GPT-4 Trained on 10x More Data, Can Write 60k Word Books',
#   'type': 'story',
#   'url': 'https://twitter.com/alexhormozi/status/1612913266195587072'},
#  {'by': 'schemescape',
#   'id': 34342573,
#   'parent': 34337152,
#   'text': 'I didn’t think the server was for DRM, but I don’t know for sure. I '
#           'like both GOG and Steam.<p>I’ll probably be kicking myself if Valve '
#           'ever gets sold, but I’m pretty happy with it for now.',
#   'time': 1673462550,
#   'type': 'comment'},
#  {'by': 'giuliomagnifico',
#   'id': 34342572,
#   'parent': 34342008,
#   'text': '100% agree but maybe who took the photo didn’t know about that a '
#           'flash can kill a fish. I didn&#x27;t know that either, maybe they '
#           'have to use some signs with written”Your flash kills the fish”, '
#           'this would be more effective!',
#   'time': 1673462549,
#   'type': 'comment'},
#  {'by': 'enragedcacti',
#   'id': 34342571,
#   'kids': [34344111],
#   'parent': 34341643,
#   'text': 'There is an extremely long and brutal history of systemic bias '
#           'against groups people who look a certain way. Pretending it must '
#           'have stopped and is now no more worthy of societal introspection '
#           'than blondes vs. brunettes is laughable to me.',
#   'time': 1673462549,
#   'type': 'comment'},
#  {'by': 'thesecretceo',
#   'descendants': 1,
#   'id': 34342570,
#   'kids': [34343100],
#   'score': 13,
#   'time': 1673462544,
#   'title': 'Major Layoffs 2023: BlackRock Reportedly Plans to Cut 500 Jobs',
#   'type': 'story',
#   'url': 'https://www.forbes.com/sites/brianbushard/2023/01/11/major-layoffs-2023-blackrock-reportedly-plans-to-cut-500-jobs/'},
#  {'by': 'newZWhoDis',
#   'id': 34342569,
#   'parent': 34342485,
#   'text': 'Calendar&#x2F;Date is the foundation for all time handling in iOS '
#           'apps. If you see a string with a date in it it was probably handled '
#           'by this system.',
#   'time': 1673462544,
#   'type': 'comment'},
#  {'by': 'yucky',
#   'id': 34342568,
#   'parent': 34340696,
#   'text': '<p><pre><code>  &gt; It doesn&#x27;t even make sense to do layoffs '
#           'today when you expect trouble 6-12 months later.\n'
#           '</code></pre>\n'
#           'It makes perfect sense. In fact, it would be crazy to wait until a '
#           'bad thing happens to prepare for it.',
#   'time': 1673462544,
#   'type': 'comment'},
#  {'by': 'xeromal',
#   'id': 34342567,
#   'parent': 34341280,
#   'text': 'Free text?',
#   'time': 1673462538,
#   'type': 'comment'},
#  {'by': 'j0yb0y',
#   'id': 34342566,
#   'parent': 34340542,
#   'text': 'Great answer! One minor point, I agree it’s not the motivation but '
#           'it _does_ provide a unified workflow across service providers, '
#           'which is valuable!',
#   'time': 1673462537,
#   'type': 'comment'},
#  {'by': 'JamesBarney',
#   'id': 34342565,
#   'parent': 34341667,
#   'text': 'I think if you&#x27;re an investor and you value companies not just '
#           'on how they are doing today but but how you think they will do in '
#           'the future you will be more successful than if you just look at '
#           'today&#x27;s numbers.',
#   'time': 1673462535,
#   'type': 'comment'},
#  {'by': 'randlet',
#   'id': 34342564,
#   'parent': 34341550,
#   'text': 'Great answer thank you!',
#   'time': 1673462531,
#   'type': 'comment'},
#  {'by': '_whiteCaps_',
#   'id': 34342563,
#   'kids': [34342969],
#   'parent': 34341021,
#   'text': 'Extension cords are a bad idea. Especially since you can buy 10A '
#           'rated cords that can be plugged into 15A sockets.<p><a '
#           'href="https:&#x2F;&#x2F;www.homedepot.com&#x2F;p&#x2F;HDX-55-ft-16-3-Green-Outdoor-Extension-Cord-1-Pack-SJTW16355GN&#x2F;320258189" '
#           'rel="nofollow">https:&#x2F;&#x2F;www.homedepot.com&#x2F;p&#x2F;HDX-55-ft-16-3-Green-Outdoor-Ext...</a><p>There&#x27;s '
#           'a really good explanation in this video:\n'
#           '<a '
#           'href="https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=K_q-xnYRugQ">https:&#x2F;&#x2F;www.youtube.com&#x2F;watch?v=K_q-xnYRugQ</a>',
#   'time': 1673462529,
#   'type': 'comment'},
#  {'by': 'hinkley',
#   'id': 34342562,
#   'kids': [34343390],
#   'parent': 34341504,
#   'text': 'I think my house has 2x200A. It was zoned multi family but the '
#           'previous owners had a separate service for an electric car, and '
#           'there’s still bits of electronics in the attic from where they '
#           'tried to do crypto mining.<p>I’m sure their equipment overheated. '
#           'The roof is not insulated and the attic fan is pushing against a '
#           'louver that’s the wrong design. It gets hot up there without any '
#           'equipment.',
#   'time': 1673462528,
#   'type': 'comment'},
#  {'by': 'MonkeyMalarky',
#   'id': 34342561,
#   'parent': 34341920,
#   'text': 'Wrong Georgia!',
#   'time': 1673462524,
#   'type': 'comment'},
#  {'by': 'stephencanon',
#   'id': 34342560,
#   'parent': 34342485,
#   'text': 'That quote is talking about the Foundation type named Calendar (<a '
#           'href="https:&#x2F;&#x2F;developer.apple.com&#x2F;documentation&#x2F;foundation&#x2F;calendar" '
#           'rel="nofollow">https:&#x2F;&#x2F;developer.apple.com&#x2F;documentation&#x2F;foundation&#x2F;calenda...</a>), '
#           'not Calendar.app.',
#   'time': 1673462516,
#   'type': 'comment'},
#  {'by': 'null0ranje',
#   'id': 34342559,
#   'parent': 34340718,
#   'text': '&gt;  Unlimited PTO is a negative signal to me honestly, and would '
#           'put me off a job.<p>This is exactly my experience. The last company '
#           'I worked for with unlimited PTO did everything to prevent folks '
#           'from using it.<p>It&#x27;s one of many negative signals I look '
#           'for.  I interviewed at a firm once that was proud that their '
#           'cafeteria offered &quot;free breakfast, lunch, and dinner&quot;, '
#           'which sounded great until you realized they expected all employees '
#           'would be working there through breakfast, lunch, and dinner.',
#   'time': 1673462514,
#   'type': 'comment'},
#  {'by': 'ilc',
#   'id': 34342558,
#   'parent': 34276228,
#   'text': '<a '
#           'href="https:&#x2F;&#x2F;www.latimes.com&#x2F;opinion&#x2F;op-ed&#x2F;la-xpm-2013-apr-07-la-oe-0407-silk-ring-theory-20130407-story.html" '
#           'rel="nofollow">https:&#x2F;&#x2F;www.latimes.com&#x2F;opinion&#x2F;op-ed&#x2F;la-xpm-2013-apr-07-la-...</a><p>Understanding '
#           'the above article is very important.  Instinctively, we want to '
#           'help.  But figuring out how to, without &quot;dumping in&quot; is '
#           'critical.<p>If you are worried about a person in the situation like '
#           'the one I was in, figure out the right way to help them.  If they '
#           'say don&#x27;t call.  Honor that.<p>As for &quot;chewing out&quot; '
#           'my wording was strong there for what I did.  Though I&#x27;d '
#           'support someone chewing out someone there.  I pointed out that my '
#           'team could make choice X without me, and that I&#x27;d left clear '
#           'directions on who could do what.  I referred them back to that '
#           'person, and reaffirmed my teams choices, which either good enough '
#           'or the exact choices I would have made.<p>Yes, the person was doing '
#           'what you suggested.  But that&#x27;s not a good thing to do.  If '
#           'they want to help me, not interrupting me is important,<p>I&#x27;d '
#           'also left my personal e-mail... so an e-mail was much more '
#           'appropriate, and would have been received better.  Also it gives me '
#           'time and space to think.  Which are precious in moments like that.  '
#           'I may not know how you can help me today.... but I may tomorrow.',
#   'time': 1673462508,
#   'type': 'comment'},
#  {'by': 'xkcd-sucks',
#   'id': 34342557,
#   'parent': 34340279,
#   'text': 'To be fair, a lot of &quot;professionals&quot; aren&#x27;t super '
#           'competent, even to the point of reading the manuals of things '
#           'they&#x27;re installing, and it&#x27;s difficult to find people '
#           'whose work isn&#x27;t sloppy and half-assed. In these cases the '
#           'only advantage hiring a contractor brings is their liability if '
#           'something goes wrong, and their ability to deliver a whole crew on '
#           'short notice.',
#   'time': 1673462496,
#   'type': 'comment'},
#  {'by': 'codemonkeysh',
#   'descendants': 13,
#   'id': 34342556,
#   'kids': [34342800, 34342791, 34343974, 34342703, 34343186, 34342676],
#   'score': 2,
#   'time': 1673462494,
#   'title': 'Ask HN: Putting aside your political views – do you support the '
#            'Fair Tax?',
#   'type': 'story'},
#  {'by': 'brickers',
#   'id': 34342555,
#   'parent': 34342309,
#   'text': 'It seems like a sensible choice that mobile isn’t your focus - I’m '
#           'just chilling on the sofa browsing HN after work… I don’t think I '
#           'know the product well enough to comment on a mobile use case, but '
#           'I’ll let you know if I think of something when I take a further '
#           'look',
#   'time': 1673462493,
#   'type': 'comment'},
#  {'by': 'epistasis',
#   'id': 34342554,
#   'parent': 34340388,
#   'text': '&gt;Hold off on appliances<p>I&#x27;m not familiar with your '
#           'utility&#x27;s challenges with delivering electricity, but it is a '
#           'very solvable problem to greatly improve '
#           'reliability.<p>Vermont&#x27;s Green Mountain Power does great work, '
#           'perhaps you can fire you utility commission and get one that will '
#           'reign in your utility&#x27;s incompetence.',
#   'time': 1673462487,
#   'type': 'comment'},
#  {'by': 'dragonwriter',
#   'id': 34342553,
#   'parent': 34341458,
#   'text': '&gt; Hispanic&#x2F;Latino is classified as an “ethnicity” not a '
#           '“race”<p>Hispanic&#x2F;Latino (and not-Hispanic&#x2F;Latino) are '
#           'the <i>only</i> ethnicities in that context, and it exists '
#           '<i>specifically</i> to enable categorization that reflects the '
#           'social construction of Whiteness at the time it was created while '
#           'not obviously breaking the (bogus, in any case) biological '
#           'rationale for the construction of “racial” categories, which is why '
#           'most categorizations of data <i>using</i> that ethnicity treat '
#           'Hispanic&#x2F;Latino as another bucket alongside the racial '
#           'buckets, from which everything of either White or every race (usage '
#           'differs) is transferred if Hispanic&#x2F;Latino ethnicity is also '
#           'indicated, leaving the effected race buckets with only the '
#           'non-Hispanic&#x2F;Latino elements.',
#   'time': 1673462484,
#   'type': 'comment'},
#  {'by': 'altairprime',
#   'id': 34342552,
#   'parent': 34341813,
#   'text': 'If they could get back on track without changing their leave '
#           'schedule, then the performance plan was well-written.',
#   'time': 1673462483,
#   'type': 'comment'},
#  {'by': 'namaria',
#   'id': 34342551,
#   'parent': 34342378,
#   'text': 'Yeah that was such a &#x27;social media hot take&#x27; kinda thing '
#           'I didn&#x27;t even feel like getting into that conversation. '
#           'Misaligned interests make it a good idea to get into a project, '
#           'slash things to the bone, cut a fat bonus check due to savings '
#           'achieve, cut and run. That&#x27;s how we got the supply chain mess '
#           'of 2021...',
#   'time': 1673462480,
#   'type': 'comment'},
#  {'by': 'Beaver117',
#   'id': 34342550,
#   'parent': 34341956,
#   'text': 'You know we&#x27;re in a recession if even Microsoft is changing '
#           'their vacation policy',
#   'time': 1673462478,
#   'type': 'comment'},
#  {'by': 'pritambaral',
#   'id': 34342549,
#   'kids': [34342859],
#   'parent': 34323257,
#   'text': 'One thing I find missing in every such platform (except Retool) is '
#           'a user editable code library. It&#x27;s one thing to be able run '
#           'code in query transformation and widgets, another thing to be able '
#           'to organise common code patterns into functions and use them in '
#           'multiple query transforms and widgets. Once an app grows large '
#           'enough, this becomes really important. Otherwise, there&#x27;s '
#           'always a build-up of copied and pasted code that&#x27;s a nightmare '
#           'to update (or even use) later.<p>The best I could find was just '
#           'this: &quot;ToolJet allows you to internally utilize the Moment, '
#           'Lodash, and Axios libraries&quot;. But what if that&#x27;s not '
#           'enough? What if I need another library to use? I know, I can add it '
#           'to a fork I self-host, but that&#x27;s still not &quot;user '
#           'editable&quot;.',
#   'time': 1673462473,
#   'type': 'comment'},
#  {'by': 'lowbloodsugar',
#   'id': 34342548,
#   'parent': 34339134,
#   'text': 'You are responding in a discussion about a lengthy article about '
#           'the unexpected deepness of a movie, written by a professional '
#           'author. Your response is that the movie is &quot;bland, very '
#           'shallow&quot; etc, without evidence, and without discussing or '
#           'refuting any of the points of the article.<p>I wonder if:<p>1. You '
#           'simply didn&#x27;t read the article. Your decision to comment in a '
#           'discussion about this article without even reading it suggests that '
#           'you might be someone who finds things boring and shallow because '
#           'you simply don&#x27;t engage with the material deeply (in this case '
#           '<i>not at all</i>). So the problem might be you.<p>2. You did read '
#           'the article fully, but yet don&#x27;t have any counter points, or '
#           'couldn&#x27;t be bothered to share them. The article provides '
#           'significant and convincing arguments that the movie is rich, deep '
#           'and funny, yet you have no rebuttals. It may be that things seem '
#           'shallow to you simply because you are incapable of deep thought. So '
#           'the problem might be you.<p>3. You are just a troll.<p>4. Some '
#           'other reason.',
#   'time': 1673462471,
#   'type': 'comment'},
#  {'by': 'projektfu',
#   'id': 34342547,
#   'parent': 34336676,
#   'text': 'As a suburban white kid a few years younger than the characters, my '
#           'first watch through the Breakfast Club saw it as a subversive film '
#           'about cool, rebellious teens making space for themselves.  Later, '
#           'it seemed like a time capsule of the oddity of our society trapping '
#           'kids in a liminal space between childhood and adulthood and '
#           'punishing them for their reactions.  They&#x27;re all helpless, '
#           'even the &quot;bad one&quot; who makes his escape attempt.<p>The '
#           'light read is that we are not merely our cliques and labels.',
#   'time': 1673462470,
#   'type': 'comment'},
#  {'by': 'xalava',
#   'id': 34342546,
#   'parent': 34330198,
#   'text': 'I realize that I have been using shell scripts for this. I just '
#           'copy-paste commands and add a selector. It has the benefit that I '
#           'didn&#x27;t need to learn a new syntax.',
#   'time': 1673462468,
#   'type': 'comment'},
#  {'by': 'ktfth',
#   'id': 34342545,
#   'parent': 34342438,
#   'text': 'Awesome content! Very interesting how the process of a tool deal '
#           'with the wires behind the scenes.',
#   'time': 1673462465,
#   'type': 'comment'},
#  {'by': 'eightysixfour',
#   'id': 34342544,
#   'kids': [34342604],
#   'parent': 34342220,
#   'text': 'Most of the CAD applications have a proprietary source format and '
#           'can export into more portable formats. I’m not sure I’m aware of a '
#           'single, portable “source format,” do you know of one?',
#   'time': 1673462458,
#   'type': 'comment'},
#  {'by': 'Apocryphon',
#   'id': 34342543,
#   'parent': 34338889,
#   'text': 'Haven&#x27;t there been studies that people without ADHD do not '
#           'benefit from amphetamines? Not to mention, there are meds that '
#           'aren&#x27;t amphetamine- Ritalin isn&#x27;t one!',
#   'time': 1673462457,
#   'type': 'comment'},
#  {'by': 'sprash',
#   'id': 34342542,
#   'parent': 34338783,
#   'text': 'Not Semantics. It shows how Wayland forces a Gnome&#x2F;GTK and '
#           'KDE&#x2F;Qt duopoly and cuts out the long tail of hobbyists and '
#           'power users. The latter is the interesting part about the '
#           'FOSS&#x2F;Linux-Desktop ecosystem. With Wayland the FOSS-Desktop '
#           'will be 100% corporate controlled. If essential things were '
#           'properly standardized this wouldn&#x27;t happen. Therefore '
#           'it&#x27;s obviously done on purpose as means for sabotage.',
#   'time': 1673462456,
#   'type': 'comment'},
#  {'by': 'smileysteve',
#   'id': 34342541,
#   'parent': 34340557,
#   'text': 'I disagree, a few notes.<p>Most carriers haven&#x27;t switched all '
#           'services yet, sms haven&#x27;t converted from 4g to 5g; some phone '
#           'call processes haven&#x27;t. If phones have to be connected to both '
#           '4g and 5g few of the benefits will be fully seen yet (congestion, '
#           'battery life, coverage)<p>TMobile relaunched mobile broadband as a '
#           'high-speed service, t-mobile announced a wireless video service.',
#   'time': 1673462454,
#   'type': 'comment'},
#  {'by': 'ckastner',
#   'descendants': 3,
#   'id': 34342540,
#   'kids': [34343308, 34344050],
#   'score': 4,
#   'time': 1673462454,
#   'title': 'Failed crypto exchange FTX has recovered over $5B, attorney says',
#   'type': 'story',
#   'url': 'https://www.reuters.com/business/finance/ftx-seeks-court-rulings-asset-sales-customer-privacy-2023-01-11/'},
#  {'by': 'Dylan16807',
#   'id': 34342539,
#   'parent': 34341678,
#   'text': 'I think you should try actually saying that out loud.  If I '
#           'don&#x27;t pause after the word &quot;wheel&quot;, I can say that '
#           'at a reasonable pace in two seconds.<p>Just &quot;Warning, take the '
#           'wheel!&quot; gives you time to pause between each repetition and '
#           'still say it 5 times.',
#   'time': 1673462453,
#   'type': 'comment'},
#  {'by': 'kllrnohj',
#   'id': 34342538,
#   'parent': 34334199,
#   'text': 'Anandtech sadly only tested 2 games in a fairly narrow set of '
#           'parameters. If you look at 13900K reviews, such as this one by '
#           'techpowerup: <a '
#           'href="https:&#x2F;&#x2F;www.techpowerup.com&#x2F;review&#x2F;intel-core-i9-13900k&#x2F;22.html" '
#           'rel="nofollow">https:&#x2F;&#x2F;www.techpowerup.com&#x2F;review&#x2F;intel-core-i9-13900k&#x2F;22.h...</a> '
#           'you&#x27;ll see gaming loads where the 13900K uses well past 120w. '
#           'Civ 6, for example, sits at nearly 190w.<p>But also again remember '
#           'the 13600 non-K has much less L2 than the 13600k. It&#x27;s not '
#           '<i>just</i> a power&#x2F;turbo restriction.<p>But we&#x27;ll see '
#           'for sure when the 13th gen non-K reviews happen. That Intel '
#           'didn&#x27;t sample these to reviewers isn&#x27;t a great sign, '
#           'though.',
#   'time': 1673462452,
#   'type': 'comment'},
#  {'by': 'PebblesRox',
#   'id': 34342537,
#   'parent': 34341675,
#   'text': 'That’s it, thank you!',
#   'time': 1673462449,
#   'type': 'comment'},
#  {'by': 'zitterbewegung',
#   'id': 34342536,
#   'parent': 34339608,
#   'text': 'If we have near 2 percent unemployment it almost begs the question '
#           'that do we need more people to seek employment ? And I don’t mean '
#           'large layoffs or pushing people to go into trades school or '
#           'disregarding going to college. It seems like all of these articles '
#           'are saying we need more X people doing Y but doesn’t look at the '
#           'whole picture that either people don’t want to do it because of '
#           'risk but instead just are doing another job.',
#   'time': 1673462436,
#   'type': 'comment'},
#  {'by': 'TheCapn',
#   'id': 34342535,
#   'parent': 34342241,
#   'text': 'Industrial Controls &#x2F; Instrumentation Tech<p>Biggest downside '
# ...
#            34343821,
#            34343489,
#            34343552,
#            34343590,
#            34343786,
#            34343777,
#            34343911,
#            34343646,
#            34342575,
#            34343115,
#            34343344,
#            34343618,
#            34343887,
#            34343372,
#            34343711,
#            34343698,
#            34343435,
#            34342356,
#            34344505,
#            34342739,
#            34344141,
#            34342821,
#            34342591,
#            34343800,
#            34343731,
#            34343329,
#            34343248,
#            34343081,
#            34342784,
#            34343554,
#            34342996,
#            34342236],
#   'score': 39,
#   'time': 1673461065,
#   'title': "It's time to stop texting",
#   'type': 'story',
#   'url': 'https://dfeldman.medium.com/its-time-to-stop-texting-6fcce2014e36'},
#  {'by': 'manv1',
#   'id': 34342165,
#   'parent': 34338527,
#   'text': 'Maybe China wants to dip a toe into great power style politics, so '
#           'it can see what being on the world stage actually entails?<p>After '
#           'all, China is looking for friends, and what better way to make '
#           'friends than to prop up a failing regime? Propping up Haiti '
#           'can&#x27;t be more expensive than propping up North Korea.',
#   'time': 1673461060,
#   'type': 'comment'},
#  {'by': 'mzs',
#   'id': 34342164,
#   'parent': 34338680,
#   'text': 'I want to point out that lower-case is possible with ITA2. Start at '
#           '4.6 of ITU-T Recommendation S.2 &#x2F; 11&#x2F;1988 in the Blue '
#           'Book, basically 11111 &amp; 11011 11111 switch case in '
#           'locking&#x2F;unlocking mode.',
#   'time': 1673461060,
#   'type': 'comment'},
#  {'by': 'navaneethpk',
#   'id': 34342163,
#   'parent': 34341486,
#   'text': 'Reddit has given us a lot of users. Especially r&#x2F;selfhosted.',
#   'time': 1673461060,
#   'type': 'comment'},
#  {'by': 'clairity',
#   'id': 34342162,
#   'parent': 34341196,
#   'text': 'yes, another restatement of the distinction between '
#           '&#x27;plan&#x27; and &#x27;workflow&#x27; as used in the talk.',
#   'time': 1673461058,
#   'type': 'comment'},
#  {'by': 'imsky',
#   'descendants': 0,
#   'id': 34342161,
#   'score': 1,
#   'time': 1673461057,
#   'title': 'First Year as a Founder',
#   'type': 'story',
#   'url': 'https://imsky.co/notes/first-year-as-a-founder/'},
#  {'by': 'aembleton',
#   'id': 34342160,
#   'kids': [34343010],
#   'parent': 34341537,
#   'text': 'They also have American Indian or Alsaka Native',
#   'time': 1673461057,
#   'type': 'comment'},
#  {'by': 'r00fus',
#   'id': 34342159,
#   'kids': [34342683],
#   'parent': 34340286,
#   'text': 'I am truly amazed at the mythology of &quot;high performers&quot; '
#           'as separate from the org.  Teams can be high performing, but high '
#           'performing individuals are often built by the environment.<p>Yet, '
#           'in the US we have this almost Stakhanovite mythology where a single '
#           'worker can pull an entire organization.<p>I have worked with '
#           'individuals who had been pariahs in the previous org (got that info '
#           'over beers with the individual) but were rockstars in our org.   '
#           'Also with so-called high-fliers from other teams&#x2F;companies who '
#           'just cratered when they joined our group.<p>Personally I think '
#           'cutting 10% pay is preferable because a) the work doesn&#x27;t go '
#           'away - if 10% are let go, I&#x27;ll probably end up doing 10%+ more '
#           'work.  b) it&#x27;s a commitment by the organization and that shows '
#           'they care enough to not unilaterally make a decision.',
#   'time': 1673461054,
#   'type': 'comment'},
#  {'by': 'mtlmtlmtlmtl',
#   'id': 34342158,
#   'kids': [34342790],
#   'parent': 34341941,
#   'text': 'No doubt the US has more of a history with deep racial division '
#           'than most other western democracies.<p>But is the race of someone '
#           'voting really useful, or is it just a fairly good proxy for other '
#           'demographics. And at what point does this use of race as a '
#           'demographic in itself become a societal pressure for blacks, '
#           'latinos, asians etc to fit into certain stereotypes?',
#   'time': 1673461053,
#   'type': 'comment'},
#  {'by': 'henning',
#   'id': 34342157,
#   'parent': 34342036,
#   'text': 'I&#x27;ve been waiting for the other shoe to drop for a decade.',
#   'time': 1673461053,
#   'type': 'comment'},
#  {'by': 'Whinner',
#   'id': 34342156,
#   'parent': 34341358,
#   'text': 'As a counter point, I paid about $1600 in 2019 in northern NJ to '
#           'have my circuit breaker panel replaced and my service upgraded from '
#           '100 to 200.',
#   'time': 1673461042,
#   'type': 'comment'},
#  {'by': 'Jensson',
#   'id': 34342155,
#   'parent': 34341708,
#   'text': 'I&#x27;m talking about how USA sees race and the forms you fill in '
#           'there, not reality of human ancestry. USA has a very antiquated '
#           'view on race, but that is the legal definition so that is what we '
#           'talk about when we are talking about race with respect to US '
#           'employment laws.',
#   'time': 1673461041,
#   'type': 'comment'},
#  {'by': 'wpietri',
#   'id': 34342154,
#   'kids': [34342248],
#   'parent': 34341880,
#   'text': 'I can only hope you&#x27;re trolling here. But on the off chance '
#           'that is a sincere question, maybe read the books I '
#           'recommended.<p>Or if you&#x27;d like a quick answer from the '
#           'Confederacy&#x27;s Vice President, you might read the Cornerstone '
#           'Speech, which includes these words: &quot;Our new '
#           'government[&#x27;s]...foundations are laid, its cornerstone rests '
#           'upon the great truth, that the negro is not equal to the white man; '
#           'that slavery—subordination to the superior race—is his natural and '
#           'normal condition. This, our new government, is the first, in the '
#           'history of the world, based upon this great physical, '
#           'philosophical, and moral truth.&quot;<p>If you&#x27;re having '
#           'trouble seeing the racism there, I&#x27;m not sure how else I could '
#           'help.',
#   'time': 1673461040,
#   'type': 'comment'},
#  {'deleted': True, 'id': 34342153, 'time': 1673461036, 'type': 'story'},
#  {'by': 'genderwhy',
#   'id': 34342152,
#   'kids': [34342305],
#   'parent': 34342083,
#   'text': 'I would associate N&#x2F;A more with agender (someone who has no '
#           'gender) more than someone who has a gender but it is not listed. '
#           'For me, my gender <i>is</i> applicable, it&#x27;s just not in that '
#           'list.<p>&quot;Not Listed&quot; might be a better title for '
#           'N&#x2F;A?<p>Edit: Just saw your edit, makes more sense. Still feels '
#           'a little on the edge for me, but we&#x27;re all going to have '
#           'different needs out of something like this.',
#   'time': 1673461034,
#   'type': 'comment'},
#  {'by': 'Guid_NewGuid',
#   'id': 34342151,
#   'parent': 34341653,
#   'text': 'I can only speak to the UK who remain a European (if not EU) '
#           'country. My understanding having been through it in my first job, '
#           'is in the UK you must make a given number of a specific role '
#           'redundant. So it&#x27;s not the people you&#x27;re laying off but '
#           'instead you say, we&#x27;re making cuts to 4 sales positions. There '
#           'is then a required consultation period where the people to be laid '
#           'off are identified so there&#x27;s always forewarning that cuts are '
#           'happening but not to who.<p>So it&#x27;s not firing but it&#x27;s '
#           'still perfectly possible to reduce headcount. What you can&#x27;t '
#           'do is the standard US move of firing everyone with zero notice by '
#           'email.',
#   'time': 1673461031,
#   'type': 'comment'},
#  {'by': 'jrochkind1',
#   'id': 34342150,
#   'parent': 34340003,
#   'text': '&gt; Shrinkage can also be attributed to product damage and loss of '
#           'goods, theft by employees and vendor fraud.<p>I&#x27;m not sure '
#           'what Dr. Su was referring to when they said &quot;it all comes down '
#           'to employees,&quot; it might not be stopping theft from the '
#           'public.  Internal theft obviously is about employees, and product '
#           'damage and to some extent vendor fraud are also things more '
#           'obviously effected by employees.',
#   'time': 1673461022,
#   'type': 'comment'},
#  {'by': 'vel0city',
#   'id': 34342149,
#   'parent': 34340993,
#   'text': '&gt; Are you trying to say that the risk to lose electricity is '
#           'bigger than the risk to lose the other heat sources?<p>From my '
#           'personal experiences, yes. Gas pipelines are practically always '
#           'buried, electricity lines are often overhead and subject to storm '
#           'damage. There have been dozens of times in my life where '
#           'electricity is out but natural gas infrastructure is still '
#           'available.',
#   'time': 1673461019,
#   'type': 'comment'},
#  {'by': 'geox',
#   'descendants': 0,
#   'id': 34342148,
#   'score': 1,
#   'time': 1673461014,
#   'title': 'The first life in our solar system may have been on Mars',
#   'type': 'story',
#   'url': 'https://healthsciences.ku.dk/newsfaculty-news/2022/11/mars-was-covered-by-300-metre-deep-oceans/'},
#  {'by': 'beardyw',
#   'id': 34342147,
#   'kids': [34343656],
#   'parent': 34341326,
#   'text': 'On my phone the bird button is mostly lost off the bottom of the '
#           'screen. Worked out what it was by deduction.',
#   'time': 1673461005,
#   'type': 'comment'},
#  {'by': 'barathr',
#   'descendants': 0,
#   'id': 34342146,
#   'score': 1,
#   'time': 1673461005,
#   'title': 'Martin Luther King: The Three Evils of Society (1967)',
#   'type': 'story',
#   'url': 'https://www.youtube.com/watch?v=j8d-IYSM-08'},
#  {'by': 'saluki',
#   'id': 34342145,
#   'parent': 34340986,
#   'text': 'Check out the YoLink temperature sensors on Amazon. They are '
#           'amazing for monitoring our secondary freezer. All their sensors '
#           'have been great. Temp for fridge&#x2F;freezers, leak detectors, '
#           'temp+humidity for basement, they have a motion sensor that is a '
#           'magnet you can place in the back of your mailbox if you want to '
#           'know when mail is delivered. Their door sensor can be installed on '
#           'overhead garage doors by a magnet and a velcro strip for the part '
#           'that goes on the wall. They also have a 1&#x2F;4 mile range and the '
#           'sensor can be inside your fridge&#x2F;freezer and still connect. '
#           'App is great, no monthly fee, you get notifications on your phone '
#           'you can also get a small number of SMS messages for free. All '
#           'notifications&#x2F;limits are configurable.',
#   'time': 1673461004,
#   'type': 'comment'},
#  {'by': 'bombcar',
#   'id': 34342144,
#   'parent': 34341984,
#   'text': 'Interconnectivity is separate from mains (though both may be '
#           'required) - the modern ones have to be set that if ONE goes off, '
#           'ALL go off.<p>For those playing at home, get the ones that are BOTH '
#           'ionization AND photoelectric: <a '
#           'href="https:&#x2F;&#x2F;www.nfpa.org&#x2F;Public-Education&#x2F;Staying-safe&#x2F;Safety-equipment&#x2F;Smoke-alarms&#x2F;Ionization-vs-photoelectric" '
#           'rel="nofollow">https:&#x2F;&#x2F;www.nfpa.org&#x2F;Public-Education&#x2F;Staying-safe&#x2F;Safety-eq...</a>',
#   'time': 1673461001,
#   'type': 'comment'},
#  {'deleted': True,
#   'id': 34342143,
#   'parent': 34342036,
#   'time': 1673461000,
#   'type': 'comment'},
#  {'by': 'dtx1',
#   'id': 34342142,
#   'parent': 34340557,
#   'text': 'I never quite understood the need to make &quot;5G&quot; this '
#           'standalone solutions to all problems of the future. It was by '
#           'definition a bundle of technologies that improved upon existing '
#           'tech. Nothing fundamentally new was ever going to happen. Phones '
#           'have internet now, they will have internet after 5G.',
#   'time': 1673460999,
#   'type': 'comment'},
#  {'by': 'acdha',
#   'id': 34342141,
#   'parent': 34339944,
#   'text': '&gt; The first is a company like Google, where their tech enables a '
#           'step-function increase in human productivity. Google Search gave '
#           'people a super power they never had before. This type of company is '
#           'extremely valuable as they can capture the value of the '
#           'productivity they unlock. The second type of tech company is '
#           'something like WeWork.<p>There’s another distinction to consider: '
#           'WeWork, Uber, etc. have most of their costs scaling with every '
#           'customer and limited competitive moat (people who travel heavily '
#           'might value sticking with one global app, but locals don’t). Google '
#           'or Facebook have costs to get started but their costs to go from 1M '
#           'users to 10M aren’t linear, and that’s really what VCs are looking '
#           'for. A lot of the bubble came from deliberately misrepresenting '
#           'companies in the former group as having the revenue potential of '
#           'the latter.',
#   'time': 1673460991,
#   'type': 'comment'},
#  {'by': 'ragingroosevelt',
#   'id': 34342140,
#   'parent': 34340132,
#   'text': 'Is it still possible to get Youtube Vanced?  Last I&#x27;d read it '
#           'got taken down.',
#   'time': 1673460982,
#   'type': 'comment'},
#  {'by': 'DanielBMarkham',
#   'id': 34342139,
#   'kids': [34342879],
#   'parent': 34329656,
#   'text': 'I keep reading these microservice essays where the author is lost '
#           'and I really feel their pain. In that spirit, let me try to make '
#           'things as simple as possible.<p>(True) Microservices have no '
#           'dependencies on anything but unstructured text data. They do not '
#           'couple to a database, the business understanding of what it&#x27;s '
#           'doing, a domain model, or anything else. They perform a simple, '
#           'idempotent, business task that can never fail although it can '
#           'create various error chains.<p>Programming at scale is tough. '
#           'There&#x27;s no free ride here. All you&#x27;ve done is turn the '
#           'traditional model of coding &quot;inside-out&quot; and now '
#           'you&#x27;ve got a ton of work doing all of the wiring.<p>But if you '
#           'keep your microservice doing one simple useful business thing, then '
#           'all of that inside-out work become business decisions. What do we '
#           'do if the sign-up fails? How do we move IMPORTANT-THING to those '
#           'other guys to use? You still have business coupling: things change '
#           'and you have to adapt. But you&#x27;re not coupled at the _coding_ '
#           'level. If there&#x27;s any magic, that&#x27;s it. Your business '
#           'should be able to wander all over the place and your microservices '
#           'hold up just fine. The old way, where we may have coupled every '
#           'little business need or want with every piece of code in the '
#           'system, was not only a pain, more importantly it was impossible to '
#           'keep organized in any one person&#x27;s head and aligned with '
#           'everyone else at scale.<p>What I see is a lot of drift. Folks start '
#           'coupling things up, perhaps by trying to create one domain model to '
#           'rule them all. They start creating microservices to do _system_ '
#           'activities, like flushing a cache. There should be a one-to-one '
#           'correspondence between your microservices and interesting business '
#           'conversations. That&#x27;s a hella discipline to maintain. It may '
#           'force a lot of conversations you thought you could avoid by hiding '
#           'them in a class hierarchy somewhere. Once you start drifting, '
#           'pretty soon you&#x27;re writing essays like this. And then here we '
#           'are&#x2F;',
#   'time': 1673460982,
#   'type': 'comment'}]

# %% [markdown]
# 2. Write a function to display all the items written by a certain user

# %%
def us_it(user):
    all_user = []
    for i in data: #something here??
        print('y')
        for key in i.keys():
            if key == 'by':
                print('y')
            #if usern == user:
                all_user.append(i)       

    return all_user, "Okay that's the end of the first one.", len(data)
print(us_it('tosh'))
#if I was working from scratch, I could do it like this:
data = []
def user_items(user):
    baseurl = 'https://hacker-news.firebaseio.com/v0/item/'
    userurl = 'https://hacker-news.firebaseio.com/v0/user/'
    user_url = user+'.json'
    response = requests.get(userurl+user_url)
    new_response = response.json()
    data.append(new_response)
    #now data contains the info for a user
    user_info = data[0]
    submitted = []
    for value in user_info['submitted']:
        submitted.append(value)
    #the submitted list has all of the item ids for the user
    submitted2 = []
    submitted2 = [str(val) for val in submitted]
    items_info = []
    for i in submitted2[:2]:
        #in this for loop, remove the 2 above and get everything. 
        # It seems like there is way too much to print out quickly, but it should work,
        #because it works this way 
        response = requests.get(baseurl+i+'.json')
        new_response = response.json()
        items_info.append(new_response)
    return items_info
user_items('tosh')
# Out:
# y
# ([], "Okay that's the end of the first one.", 1)
# [{'by': 'tosh',
#   'descendants': 0,
#   'id': 34342636,
#   'score': 2,
#   'time': 1673462786,
#   'title': 'iOS 16.3, macOS Ventura 13.2 Betas: Physical Apple ID Security Keys',
#   'type': 'story',
#   'url': 'https://www.macrumors.com/2022/12/14/ios-16-3-beta-security-keys/'},
#  {'by': 'tosh',
#   'descendants': 0,
#   'id': 34338576,
#   'score': 2,
#   'time': 1673445961,
#   'title': 'Irem M92',
#   'type': 'story',
#   'url': 'https://www.system16.com/hardware.php?id=747'}]

# %% [markdown]
# 3. Write a function to display the average score of all items

# %%
def avg_scores():
    data = []
    baseurl = 'https://hacker-news.firebaseio.com/v0/item/'
    item = 34342638
    for _ in range(50):
        sitem = str(item)+'.json'
        response = requests.get(baseurl+sitem)
        new_response = response.json()
        if 'score' in new_response.keys():
            if new_response['score'] != None:
                data.append(new_response['score'])
        item -= 1     
            
    return sum(data)/len(data)    
        

print(avg_scores())
# Out:
# 2.2

# %% [markdown]
# 4. Write a function to display the average score of the items by a certain user

# %%
data = []
def user_scav(user):
    baseurl = 'https://hacker-news.firebaseio.com/v0/item/'
    userurl = 'https://hacker-news.firebaseio.com/v0/user/'
    user_url = user+'.json'
    response = requests.get(userurl+user_url)
    new_response = response.json()
    data.append(new_response)
    #now data contains the info for a user
    user_info = data[0]
    submitted = []
    for value in user_info['submitted']:
        submitted.append(value)
    #the submitted list has all of the item ids for the user
    submitted2 = []
    submitted2 = [str(val) for val in submitted]
    items_info = []
    for i in submitted2[:20]:
        #in this for loop, remove the 2 above and get everything. 
        # It seems like there is way too much to print out quickly, but it should work,
        #because it works this way 
        response = requests.get(baseurl+i+'.json')
        new_response = response.json()
        if 'score' in new_response.keys():
            if new_response['score'] != None:
                items_info.append(new_response['score'])
        
        return sum(items_info)/len(items_info)
user_scav('tosh')
# Out:
# 2.0

# %% [markdown]
# 5. Write a function to display all of the comments of an item(this is a more challenging task)

# %% [markdown]
# 6. Write a function to display all of the items created in a certain year. You can expand on this to add additional parameters: Month, Day, etc. Any combo you choose or any single value
# 7. Write a function to display the total number of deleted items.
# 8. Write a function to display the total number of live items.
# 9. Write a function to display the total number of deleted items without any comments
# 10. Write a function to find which item has the most total comments
# 11. Write a function to find which user made the most comments.
# 12. Write a function to see which hour of the day is the most common for a user to post an item
